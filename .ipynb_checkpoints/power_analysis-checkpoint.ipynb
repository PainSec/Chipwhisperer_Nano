# %%
print("This is SIMULATED version")
SCOPETYPE = 'CWNANO'
PLATFORM = 'CWNANO'
VERSION="SIMULATED"
# Out:
# This is SIMULATED version

# %%
# %run "password_sim.ipynb"
trace_test = cap_pass_trace("h\n")
trace_h = cap_pass_trace("h\n")
print(trace_h)
import matplotlib.pyplot as plt
# Out:
# ✔️ OK to continue!
# [-0.0234375  -0.20214844 -0.15039062 ... -0.17675781 -0.09375
#  -0.03320312]

# %%
from tqdm.notebook import tqdm
plt.figure()
for c in tqdm('abcdefghijklmnopqrstuvwxyz0123456789'):
    trace = cap_pass_trace(c + "\n")
    plt.plot(trace[0:500])
# Out:
#   0%|          | 0/36 [00:00<?, ?it/s]

# %%
# %matplotlib inline
import matplotlib.pylab as plt

plt.figure()
ref_trace = cap_pass_trace("h0p\x00\n")[0:500]

for c in 'abcdefghijklmnopqrstuvwxyz0123456789':
    trace = cap_pass_trace('h0p' + c + "\n")[0:500]
    plt.plot(trace - ref_trace)

# %%
import numpy as np
ref_trace = cap_pass_trace( "h0p\x00\n")

for c in 'abcdefghijklmnopqrstuvwxyz0123456789':
    trace = cap_pass_trace("h0p" + c + "\n")
    diff = np.sum(np.abs(trace - ref_trace))

    print("{:1} diff = {:2}".format(c, diff))
# Out:
# a diff = 6.1123046875
# b diff = 6.5009765625
# c diff = 6.2900390625
# d diff = 9.791015625
# e diff = 8.19921875
# f diff = 7.6103515625
# g diff = 5.9462890625
# h diff = 7.01171875
# i diff = 6.0849609375
# j diff = 9.2138671875
# k diff = 7.4541015625
# l diff = 6.927734375
# m diff = 8.099609375
# n diff = 6.23046875
# o diff = 7.5576171875
# p diff = 8.0703125
# q diff = 7.2216796875
# r diff = 6.1123046875
# s diff = 11.6572265625
# t diff = 7.705078125
# u diff = 6.5673828125
# v diff = 7.7109375
# w diff = 8.87109375
# x diff = 100.458984375
# y diff = 7.38671875
# z diff = 7.56640625
# 0 diff = 10.9853515625
# 1 diff = 7.705078125
# 2 diff = 6.8447265625
# 3 diff = 6.6826171875
# 4 diff = 6.28125
# 5 diff = 7.6611328125
# 6 diff = 9.435546875
# 7 diff = 11.740234375
# 8 diff = 6.0849609375
# 9 diff = 0.0

# %%
guessed_pw = ""
for _ in range(0, 5):
    ref_trace = cap_pass_trace(guessed_pw + "\x00\n")
    for c in 'abcdefghijklmnopqrstuvwxyz0123456789':
        trace = cap_pass_trace(guessed_pw + c + "\n")
        diff = np.sum(np.abs(trace - ref_trace))
        if diff > 40.0:
            guessed_pw += c
            print(guessed_pw)
            break
# Out:
# h
# h0
# h0p
# h0px
# h0px3
